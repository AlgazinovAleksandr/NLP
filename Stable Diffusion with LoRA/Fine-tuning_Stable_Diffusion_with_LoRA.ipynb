# %% [markdown]
# # Goal of this notebook

# %% [markdown]
# # Important thing before we start
#
# **For the fine-tuning part, I used the train_text_to_image_lora.py file. Meanwhile, I did not write this script by myself, it was taken from the https://huggingface.co/blog/lora reference. Hence, the file cannot be found in this repository. Please refer to the mentioned link to get access to this file.**

# %% [markdown]
# ### Load all the necessary libraries

# %%
#! pip install git+https://github.com/huggingface/diffusers.git

# %%
#! pip install accelerate diffusers transformers datasets

# %% [markdown]
# ### Setting up the fine-tuning (see references)

# %%
import os

os.environ["MODEL_NAME"] = "CompVis/stable-diffusion-v1-4"
os.environ["DATASET_NAME"] = "AdamLucek/oldbookillustrations-small"

# %%
! mkdir fine_tuned_model

# %%
! accelerate launch train_text_to_image_lora.py \
  --pretrained_model_name_or_path=$MODEL_NAME \
  --dataset_name=$DATASET_NAME \
  --dataloader_num_workers=8 \
  --resolution=512 --center_crop --random_flip \
  --train_batch_size=1 \
  --gradient_accumulation_steps=4 \
  --max_train_steps=2501 \
  --learning_rate=3e-04 \
  --max_grad_norm=1 \
  --lr_scheduler="cosine" --lr_warmup_steps=0 \
  --output_dir="fine_tuned_model" \
  --mixed_precision="fp16" \
  --checkpointing_steps=500 \
  --seed=1337
# Out:
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_processes` was set to a value of `1`
# 	`--num_machines` was set to a value of `1`
# 	`--mixed_precision` was set to a value of `'no'`
# 	`--dynamo_backend` was set to a value of `'no'`
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# 2025-03-28 11:55:40.885899: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743162941.165331    1661 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1743162941.253917    1661 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-28 11:55:41.848369: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 03/28/2025 11:55:48 - INFO - __main__ - Distributed environment: DistributedType.NO
# Num processes: 1
# Process index: 0
# Local process index: 0
# Device: cuda
#
# Mixed precision type: fp16
#
# scheduler_config.json: 100% 313/313 [00:00<00:00, 2.60MB/s]
# {'dynamic_thresholding_ratio', 'sample_max_value', 'timestep_spacing', 'thresholding', 'variance_type', 'prediction_type', 'rescale_betas_zero_snr', 'clip_sample_range'} was not found in config. Values will be initialized to default values.
# tokenizer_config.json: 100% 806/806 [00:00<00:00, 5.46MB/s]
# vocab.json: 100% 1.06M/1.06M [00:00<00:00, 13.8MB/s]
# merges.txt: 100% 525k/525k [00:00<00:00, 8.04MB/s]
# special_tokens_map.json: 100% 472/472 [00:00<00:00, 4.33MB/s]
# config.json: 100% 592/592 [00:00<00:00, 4.56MB/s]
# model.safetensors: 100% 492M/492M [00:01<00:00, 282MB/s]
# config.json: 100% 551/551 [00:00<00:00, 4.58MB/s]
# diffusion_pytorch_model.safetensors: 100% 335M/335M [00:01<00:00, 300MB/s]
# {'mid_block_add_attention', 'use_quant_conv', 'norm_num_groups', 'latents_std', 'use_post_quant_conv', 'latents_mean', 'shift_factor', 'force_upcast'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing AutoencoderKL.
#
# All the weights of AutoencoderKL were initialized from the model checkpoint at CompVis/stable-diffusion-v1-4.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use AutoencoderKL for predictions without further training.
# config.json: 100% 743/743 [00:00<00:00, 6.36MB/s]
# diffusion_pytorch_model.safetensors: 100% 3.44G/3.44G [00:20<00:00, 170MB/s]
# {'encoder_hid_dim', 'encoder_hid_dim_type', 'only_cross_attention', 'attention_type', 'addition_time_embed_dim', 'time_cond_proj_dim', 'dual_cross_attention', 'mid_block_type', 'class_embeddings_concat', 'projection_class_embeddings_input_dim', 'time_embedding_dim', 'reverse_transformer_layers_per_block', 'conv_in_kernel', 'resnet_out_scale_factor', 'addition_embed_type_num_heads', 'cross_attention_norm', 'num_class_embeds', 'dropout', 'class_embed_type', 'num_attention_heads', 'resnet_skip_time_act', 'resnet_time_scale_shift', 'use_linear_projection', 'conv_out_kernel', 'upcast_attention', 'time_embedding_act_fn', 'timestep_post_act', 'transformer_layers_per_block', 'addition_embed_type', 'mid_block_only_cross_attention', 'time_embedding_type'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing UNet2DConditionModel.
#
# All the weights of UNet2DConditionModel were initialized from the model checkpoint at CompVis/stable-diffusion-v1-4.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use UNet2DConditionModel for predictions without further training.
# README.md: 100% 782/782 [00:00<00:00, 6.98MB/s]
# train-00000-of-00001.parquet: 100% 407M/407M [00:01<00:00, 220MB/s]
# Generating train split: 100% 1000/1000 [00:02<00:00, 351.02 examples/s]
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# 03/28/2025 11:56:28 - INFO - __main__ - ***** Running training *****
# 03/28/2025 11:56:28 - INFO - __main__ -   Num examples = 1000
# 03/28/2025 11:56:28 - INFO - __main__ -   Num Epochs = 11
# 03/28/2025 11:56:28 - INFO - __main__ -   Instantaneous batch size per device = 1
# 03/28/2025 11:56:28 - INFO - __main__ -   Total train batch size (w. parallel, distributed & accumulation) = 4
# 03/28/2025 11:56:28 - INFO - __main__ -   Gradient Accumulation steps = 4
# 03/28/2025 11:56:28 - INFO - __main__ -   Total optimization steps = 2501
# Steps:  20% 500/2501 [12:15<52:51,  1.58s/it, lr=0.000271, step_loss=0.0763]03/28/2025 12:08:44 - INFO - accelerate.accelerator - Saving current state to fine_tuned_model/checkpoint-500
# 03/28/2025 12:09:02 - INFO - accelerate.checkpointing - Model weights saved in fine_tuned_model/checkpoint-500/model.safetensors
# 03/28/2025 12:09:02 - INFO - accelerate.checkpointing - Optimizer state saved in fine_tuned_model/checkpoint-500/optimizer.bin
# 03/28/2025 12:09:02 - INFO - accelerate.checkpointing - Scheduler state saved in fine_tuned_model/checkpoint-500/scheduler.bin
# 03/28/2025 12:09:02 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in fine_tuned_model/checkpoint-500/sampler.bin
# 03/28/2025 12:09:02 - INFO - accelerate.checkpointing - Gradient scaler state saved in fine_tuned_model/checkpoint-500/scaler.pt
# 03/28/2025 12:09:02 - INFO - accelerate.checkpointing - Random states saved in fine_tuned_model/checkpoint-500/random_states_0.pkl
# Model weights saved in fine_tuned_model/checkpoint-500/pytorch_lora_weights.safetensors
# 03/28/2025 12:09:02 - INFO - __main__ - Saved state to fine_tuned_model/checkpoint-500
# Steps:  40% 1000/2501 [24:48<39:29,  1.58s/it, lr=0.000197, step_loss=0.00442]03/28/2025 12:21:17 - INFO - accelerate.accelerator - Saving current state to fine_tuned_model/checkpoint-1000
# 03/28/2025 12:21:37 - INFO - accelerate.checkpointing - Model weights saved in fine_tuned_model/checkpoint-1000/model.safetensors
# 03/28/2025 12:21:38 - INFO - accelerate.checkpointing - Optimizer state saved in fine_tuned_model/checkpoint-1000/optimizer.bin
# 03/28/2025 12:21:38 - INFO - accelerate.checkpointing - Scheduler state saved in fine_tuned_model/checkpoint-1000/scheduler.bin
# 03/28/2025 12:21:38 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in fine_tuned_model/checkpoint-1000/sampler.bin
# 03/28/2025 12:21:38 - INFO - accelerate.checkpointing - Gradient scaler state saved in fine_tuned_model/checkpoint-1000/scaler.pt
# 03/28/2025 12:21:38 - INFO - accelerate.checkpointing - Random states saved in fine_tuned_model/checkpoint-1000/random_states_0.pkl
# Model weights saved in fine_tuned_model/checkpoint-1000/pytorch_lora_weights.safetensors
# 03/28/2025 12:21:38 - INFO - __main__ - Saved state to fine_tuned_model/checkpoint-1000
# Steps:  60% 1500/2501 [37:24<26:18,  1.58s/it, lr=0.000104, step_loss=0.0288]03/28/2025 12:33:52 - INFO - accelerate.accelerator - Saving current state to fine_tuned_model/checkpoint-1500
# 03/28/2025 12:34:14 - INFO - accelerate.checkpointing - Model weights saved in fine_tuned_model/checkpoint-1500/model.safetensors
# 03/28/2025 12:34:14 - INFO - accelerate.checkpointing - Optimizer state saved in fine_tuned_model/checkpoint-1500/optimizer.bin
# 03/28/2025 12:34:14 - INFO - accelerate.checkpointing - Scheduler state saved in fine_tuned_model/checkpoint-1500/scheduler.bin
# 03/28/2025 12:34:14 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in fine_tuned_model/checkpoint-1500/sampler.bin
# 03/28/2025 12:34:14 - INFO - accelerate.checkpointing - Gradient scaler state saved in fine_tuned_model/checkpoint-1500/scaler.pt
# 03/28/2025 12:34:14 - INFO - accelerate.checkpointing - Random states saved in fine_tuned_model/checkpoint-1500/random_states_0.pkl
# Model weights saved in fine_tuned_model/checkpoint-1500/pytorch_lora_weights.safetensors
# 03/28/2025 12:34:14 - INFO - __main__ - Saved state to fine_tuned_model/checkpoint-1500
# Steps:  80% 2000/2501 [50:01<14:31,  1.74s/it, lr=2.88e-5, step_loss=0.0307]03/28/2025 12:46:30 - INFO - accelerate.accelerator - Saving current state to fine_tuned_model/checkpoint-2000
# 03/28/2025 12:46:49 - INFO - accelerate.checkpointing - Model weights saved in fine_tuned_model/checkpoint-2000/model.safetensors
# 03/28/2025 12:46:49 - INFO - accelerate.checkpointing - Optimizer state saved in fine_tuned_model/checkpoint-2000/optimizer.bin
# 03/28/2025 12:46:49 - INFO - accelerate.checkpointing - Scheduler state saved in fine_tuned_model/checkpoint-2000/scheduler.bin
# 03/28/2025 12:46:49 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in fine_tuned_model/checkpoint-2000/sampler.bin
# 03/28/2025 12:46:49 - INFO - accelerate.checkpointing - Gradient scaler state saved in fine_tuned_model/checkpoint-2000/scaler.pt
# 03/28/2025 12:46:49 - INFO - accelerate.checkpointing - Random states saved in fine_tuned_model/checkpoint-2000/random_states_0.pkl
# Model weights saved in fine_tuned_model/checkpoint-2000/pytorch_lora_weights.safetensors
# 03/28/2025 12:46:49 - INFO - __main__ - Saved state to fine_tuned_model/checkpoint-2000
# Steps: 100% 2500/2501 [1:02:35<00:01,  1.64s/it, lr=4.73e-10, step_loss=0.217]03/28/2025 12:59:04 - INFO - accelerate.accelerator - Saving current state to fine_tuned_model/checkpoint-2500
# 03/28/2025 12:59:46 - INFO - accelerate.checkpointing - Model weights saved in fine_tuned_model/checkpoint-2500/model.safetensors
# 03/28/2025 12:59:51 - INFO - accelerate.checkpointing - Optimizer state saved in fine_tuned_model/checkpoint-2500/optimizer.bin
# 03/28/2025 12:59:51 - INFO - accelerate.checkpointing - Scheduler state saved in fine_tuned_model/checkpoint-2500/scheduler.bin
# 03/28/2025 12:59:51 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in fine_tuned_model/checkpoint-2500/sampler.bin
# 03/28/2025 12:59:51 - INFO - accelerate.checkpointing - Gradient scaler state saved in fine_tuned_model/checkpoint-2500/scaler.pt
# 03/28/2025 12:59:51 - INFO - accelerate.checkpointing - Random states saved in fine_tuned_model/checkpoint-2500/random_states_0.pkl
# Model weights saved in fine_tuned_model/checkpoint-2500/pytorch_lora_weights.safetensors
# 03/28/2025 12:59:53 - INFO - __main__ - Saved state to fine_tuned_model/checkpoint-2500
# Steps: 100% 2501/2501 [1:03:26<00:00, 16.54s/it, lr=0, step_loss=0.00306]      Model weights saved in fine_tuned_model/pytorch_lora_weights.safetensors
# Steps: 100% 2501/2501 [1:03:27<00:00,  1.52s/it, lr=0, step_loss=0.00306]

# %% [markdown]
# ### Fine-tuning successfully completed

# %% [markdown]
# ### Inference

# %%
import torch
from diffusers import StableDiffusionPipeline, DPMSolverMultistepScheduler

# Load the model and scheduler
model_id = "CompVis/stable-diffusion-v1-4"
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
pipe.scheduler = DPMSolverMultistepScheduler.from_config(pipe.scheduler.config)

# Move the pipeline to the GPU
pipe = pipe.to("cuda")

# Define the prompt
prompt = "A futuristic cityscape at sunset with flying cars and neon lights"

# Generate the image
image = pipe(prompt).images[0]

# Save the image
image.save("generated_image_no_fine_tune.png")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model_index.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# Fetching 16 files:   0%|          | 0/16 [00:00<?, ?it/s]
# preprocessor_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# scheduler_config-checkpoint.json:   0%|          | 0.00/209 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/4.56k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
model_path = 'fine_tuned_model'
pipe.unet.load_attn_procs(model_path) # by default chooses the latest checkpoint, which is what we need

# Move the pipeline to the GPU
pipe = pipe.to("cuda")

# Define the prompt
prompt = "A futuristic cityscape at sunset with flying cars and neon lights"

# Generate the image
image = pipe(prompt).images[0]

# Save the image
image.save("generated_image_with_fine_tune.png")
# Out:
# /usr/local/lib/python3.11/dist-packages/diffusers/loaders/unet.py:212: FutureWarning: `load_attn_procs` is deprecated and will be removed in version 0.40.0. Using the `load_attn_procs()` method has been deprecated and will be removed in a future version. Please use `load_lora_adapter()`.
#   deprecate("load_attn_procs", "0.40.0", deprecation_message)
#   0%|          | 0/50 [00:00<?, ?it/s]

# %% [markdown]
# ### Inference works. Now let's create some prompts and test the old and the new models

# %% [markdown]
# ### Do the inference. 15 prompts in total. Generate images for each prompt with the original and with the fine-tuned model

# %%
! mkdir images_original

# %%
! mkdir images_fine_tune

# %%
prompts = ['A bald man with a long beard smiles faintly',
           'Vase with foliated ornaments',
           'A big black cat looking at the window',
           'A monkey wearing a feathered hat walks around the countryside',
           'A boy is reading a book in his bedroom',
           'A family is having a dinner',
          'A country cottage',
          'Wildflowers in a meadow',
          'A steam train on a bridge',
          'Children playing in a park',
          'A medieval castle',
          'A botanical illustration of a rose',
          'A map of Europe in the 18th century',
          'A caricature of a politician',
          'A scene from a Shakespeare play']

# %%
len(prompts)
# Out:
# 15

# %% [markdown]
# ### Original model

# %%
model_id = "CompVis/stable-diffusion-v1-4"
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
pipe.scheduler = DPMSolverMultistepScheduler.from_config(pipe.scheduler.config)
pipe = pipe.to("cuda")

i = 1
for prompt in prompts:
  image = pipe(prompt).images[0]
  image.save(f"images_original/{i}.png")
  i += 1
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
# convert the images to a convenient zip file
! zip -r images_original.zip images_original
# Out:
#   adding: images_original/ (stored 0%)
#   adding: images_original/2.png (deflated 0%)
#   adding: images_original/5.png (deflated 0%)
#   adding: images_original/12.png (deflated 0%)
#   adding: images_original/3.png (deflated 0%)
#   adding: images_original/11.png (deflated 0%)
#   adding: images_original/4.png (deflated 0%)
#   adding: images_original/13.png (deflated 0%)
#   adding: images_original/8.png (deflated 0%)
#   adding: images_original/14.png (deflated 0%)
#   adding: images_original/15.png (deflated 0%)
#   adding: images_original/9.png (deflated 0%)
#   adding: images_original/1.png (deflated 0%)
#   adding: images_original/7.png (deflated 0%)
#   adding: images_original/6.png (deflated 0%)
#   adding: images_original/10.png (deflated 0%)

# %% [markdown]
# ### Fine-Tuned model

# %%
model_path = 'fine_tuned_model'
pipe.unet.load_attn_procs(model_path)
pipe = pipe.to("cuda")

i = 1
for prompt in prompts:
  image = pipe(prompt).images[0]
  image.save(f"images_fine_tune/{i}.png")
  i += 1
# Out:
# /usr/local/lib/python3.11/dist-packages/diffusers/loaders/unet.py:212: FutureWarning: `load_attn_procs` is deprecated and will be removed in version 0.40.0. Using the `load_attn_procs()` method has been deprecated and will be removed in a future version. Please use `load_lora_adapter()`.
#   deprecate("load_attn_procs", "0.40.0", deprecation_message)
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
! zip -r images_fine_tune.zip images_fine_tune
# Out:
#   adding: images_fine_tune/ (stored 0%)
#   adding: images_fine_tune/2.png (deflated 0%)
#   adding: images_fine_tune/5.png (deflated 0%)
#   adding: images_fine_tune/12.png (deflated 1%)
#   adding: images_fine_tune/3.png (deflated 0%)
#   adding: images_fine_tune/11.png (deflated 0%)
#   adding: images_fine_tune/4.png (deflated 0%)
#   adding: images_fine_tune/13.png (deflated 0%)
#   adding: images_fine_tune/8.png (deflated 0%)
#   adding: images_fine_tune/14.png (deflated 0%)
#   adding: images_fine_tune/15.png (deflated 0%)
#   adding: images_fine_tune/9.png (deflated 0%)
#   adding: images_fine_tune/1.png (deflated 0%)
#   adding: images_fine_tune/7.png (deflated 0%)
#   adding: images_fine_tune/6.png (deflated 0%)
#   adding: images_fine_tune/10.png (deflated 0%)

# %% [markdown]
# ### Please check Results_summary.pdf file to have a look at the generated pictures, as well as my comments

# %% [markdown]
# ### References:
#
# https://huggingface.co/blog/lora - how to do LoRA on stable diffusion (code and idea were taken from there)
#
# https://huggingface.co/datasets/gigant/oldbookillustrations - original old books dataset
#
# https://huggingface.co/datasets/AdamLucek/oldbookillustrations-small?row=0 - small dataset (the one that I used)
